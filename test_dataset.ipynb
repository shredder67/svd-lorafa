# %%
from datasets import GLUEDatasetRoberta
from transformers import RobertaTokenizer
tokenizer = RobertaTokenizer.from_pretrained('roberta-base')

# %%
benchmarks = ['mrpc', 'cola', 'qnli', 'rte', 'sst2', 'stsb', 'qqp', 'mnli']
glue_dir = '../GLUE-baselines/glue_data/'
benchmark_dirs = ['MRPC/', 'CoLA/', 'QNLI/', 'RTE/', 'SST-2/', 'STS-B/', 'QQP/', 'MNLI/']

# %%
i = 0
train = GLUEDatasetRoberta(glue_dir + benchmark_dirs[i] + 'msr_paraphrase_train.txt', tokenizer, benchmark=benchmarks[i])
test = GLUEDatasetRoberta(glue_dir + benchmark_dirs[i] + 'msr_paraphrase_test.txt', tokenizer, benchmark=benchmarks[i])

# %%
i = 1
train = GLUEDatasetRoberta(glue_dir + benchmark_dirs[i] + 'train.tsv', tokenizer, benchmark=benchmarks[i])
test = GLUEDatasetRoberta(glue_dir + benchmark_dirs[i] + 'dev.tsv', tokenizer, benchmark=benchmarks[i])

# %%
i = 2
train = GLUEDatasetRoberta(glue_dir + benchmark_dirs[i] + 'train.tsv', tokenizer, benchmark=benchmarks[i])
test = GLUEDatasetRoberta(glue_dir + benchmark_dirs[i] + 'dev.tsv', tokenizer, benchmark=benchmarks[i])
# Out:
# c:\Users\ptmeg\OneDrive\Документы\Skoltech\Term2\NLA\Final Project\svd-lorafa\datasets.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.csv[label_column][self.csv[label_column].str.contains('not')] = 0
# c:\Users\ptmeg\OneDrive\Документы\Skoltech\Term2\NLA\Final Project\svd-lorafa\datasets.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.csv[label_column][self.csv[label_column] != 0] = 1
# ...

# %%
i = 3
train = GLUEDatasetRoberta(glue_dir + benchmark_dirs[i] + 'train.tsv', tokenizer, benchmark=benchmarks[i])
test = GLUEDatasetRoberta(glue_dir + benchmark_dirs[i] + 'dev.tsv', tokenizer, benchmark=benchmarks[i])
# Out:
# c:\Users\ptmeg\OneDrive\Документы\Skoltech\Term2\NLA\Final Project\svd-lorafa\datasets.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.csv[label_column][self.csv[label_column].str.contains('not')] = 0
# c:\Users\ptmeg\OneDrive\Документы\Skoltech\Term2\NLA\Final Project\svd-lorafa\datasets.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.csv[label_column][self.csv[label_column] != 0] = 1
# ...

# %%
i = 4
train = GLUEDatasetRoberta(glue_dir + benchmark_dirs[i] + 'train.tsv', tokenizer, benchmark=benchmarks[i])
test = GLUEDatasetRoberta(glue_dir + benchmark_dirs[i] + 'dev.tsv', tokenizer, benchmark=benchmarks[i])

# %%
i = 5
train = GLUEDatasetRoberta(glue_dir + benchmark_dirs[i] + 'train.tsv', tokenizer, benchmark=benchmarks[i])
test = GLUEDatasetRoberta(glue_dir + benchmark_dirs[i] + 'dev.tsv', tokenizer, benchmark=benchmarks[i])
# Out:
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.

# %%
i = 6 
train = GLUEDatasetRoberta(glue_dir + benchmark_dirs[i] + 'train.tsv', tokenizer, benchmark=benchmarks[i])
test = GLUEDatasetRoberta(glue_dir + benchmark_dirs[i] + 'dev.tsv', tokenizer, benchmark=benchmarks[i])
# Out:
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# ...

# %%
i = 7
train = GLUEDatasetRoberta(glue_dir + benchmark_dirs[i] + 'train.tsv', tokenizer, benchmark=benchmarks[i])
test = GLUEDatasetRoberta(glue_dir + benchmark_dirs[i] + 'dev_matched.tsv', tokenizer, benchmark=benchmarks[i])
# Out:
# c:\Users\ptmeg\OneDrive\Документы\Skoltech\Term2\NLA\Final Project\svd-lorafa\datasets.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.csv[label_column][self.csv[label_column]=='neutral'] = 0
# c:\Users\ptmeg\OneDrive\Документы\Skoltech\Term2\NLA\Final Project\svd-lorafa\datasets.py:77: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.csv[label_column][self.csv[label_column]=='entailment'] = 1
# c:\Users\ptmeg\OneDrive\Документы\Skoltech\Term2\NLA\Final Project\svd-lorafa\datasets.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...
